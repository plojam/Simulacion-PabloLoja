# %%
import math
import random
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Distribucion de cauchy
#
# #### Enunciado
#
# El ministerio del ambiente comenzo un proyecto donde requiere calcular el aumento y la disminucion del caudal del rio Yanuncay ubicado en Cuenca, para este estudio se evalua la cantidad de lluvia presentada diariamente (representada en valores de 0 a 1) por 100 dias.

# %%
iteraciones = 100

#numeros
random.seed(496001)
r = []
[r.append(random.random())for i in range(iteraciones)]

r = sorted(r)

#normal
densidad = []

for i in range(iteraciones):
    #tan pi u 
    resultado = 1/(math.pi*(1+r[i]*r[i]))
    densidad.append(resultado)



#inversa
inversa = []

for i in range(iteraciones):
    #tan pi u 
    #resultado = np.abs(math.tan(math.pi*(r[i]-0.5)))
    resultado = math.tan(math.pi*(r[i]-0.5))
    inversa.append(resultado)

# %%
print('i \t xi \t resultado')
for i in range(iteraciones):
    print(str(i+1) + ' \t ' + str(r[i]) + ' \t ' + str(inversa[i]))
# Out:
# i 	 xi 	 resultado
# 1 	 0.007757864653073154 	 -41.02248142966869
# 2 	 0.018122088254503232 	 -17.545764988399252
# 3 	 0.025899305677476003 	 -12.263152804056864
# 4 	 0.032358684315577424 	 -9.803013702050938
# 5 	 0.03387229210297704 	 -9.361855223205996
# 6 	 0.03465890950940764 	 -9.147747569095236
# 7 	 0.050832149819178385 	 -6.2086575955086545
# 8 	 0.06571600769793651 	 -4.774705182526915
# 9 	 0.08708199509913683 	 -3.5636389835122033
# 10 	 0.10010937981842527 	 -3.0740888317794672
# 11 	 0.10073878574423167 	 -3.0535504320929747
# 12 	 0.10395439481940505 	 -2.9523719317286417
# 13 	 0.10429460682330371 	 -2.94201952657018
# 14 	 0.12713116415260628 	 -2.369222097175222
# 15 	 0.13814419710895842 	 -2.1576717457708083
# 16 	 0.14354739199592614 	 -2.0650541676824887
# 17 	 0.15012443197016756 	 -1.9607153045178967
# 18 	 0.1587305218192605 	 -1.836302942671637
# 19 	 0.16720835417789492 	 -1.7252637600701395
# 20 	 0.1696702937149197 	 -1.694912008540212
# ...

# %%
plt.title('Grafico Función')
plt.xlabel('Valores')
plt.ylabel('Resultado')
plt.plot(r,densidad)
plt.show()

# %%
plt.title('Grafico Función')
plt.xlabel('Valores')
plt.ylabel('Resultado')
plt.plot(r,inversa)
plt.show()
